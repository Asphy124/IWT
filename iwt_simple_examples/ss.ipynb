# %%
import numpy as np
def sax_Gauss(x):
    mm = (3.2**2) * (0.1**2)
    t = np.pi * x / 0.1
    ss = np.sin(t)
    ee = np.exp(-np.square(x) / (2 * mm))
    return ss * ee / t

# %%
x = np.arange(-1,1,1/1000)
y = sax_Gauss(x)
from matplotlib import pyplot as plt 
plt.plot(x, y)
